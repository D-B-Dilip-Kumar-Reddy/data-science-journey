# %% [markdown]
# # Environment Check Notebook
#
# This notebook verifies that the local environment is ready for data science work.
# It is intentionally simple and focuses on validation, not learning.

# %%
import sys
sys.version
# Out:
# '3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]'

# %%
import numpy as np
import pandas as pd

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
# Out:
# NumPy version: 2.3.5
# Pandas version: 2.3.3

# %%
print("Environment check complete")
# Out:
# Environment check complete
