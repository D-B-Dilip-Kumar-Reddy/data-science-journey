# %%
import sys

# %%
sys.version
# Out:
# '3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]'

# %%
sys.executable
# Out:
# 'c:\\Users\\dil91\\anaconda3\\envs\\ds_env\\python.exe'

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame({
    "iteration": [1, 2, 3],
    "status": ["PASS", "PASS", "FAIL"]
})
df
# Out:
#    iteration status
# 0          1   PASS
# 1          2   PASS
# 2          3   FAIL
