# %%
import sys

# %%
sys.version
# Out:
# '3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]'

# %%
sys.executable
# Out:
# 'c:\\Users\\dil91\\anaconda3\\envs\\ds_env\\python.exe'

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame({
    "iteration": [1, 2, 3],
    "status": ["PASS", "PASS", "FAIL"]
})
df
# Out:
#    iteration status
# 0          1   PASS
# 1          2   PASS
# 2          3   FAIL

# %% [markdown]
# ☐ Conda env created (ds_env)
#
# ☐ Python 3.11 active
#
# ☐ ipykernel installed
#
# ☐ Notebook runs without prompts
#
# ☐ NumPy & Pandas import OK
#
# everything done via VS code, Conda prompt

# %% [markdown]
# Created  env in VS code terminal:
#
#         conda create -n ds_env python=3.11 -y
#
# Changed terminal to powershell in VS code to use the conda environment
#
#         conda activate ds_env
#
# install ipykernel
#
#         conda install ipykernel -y
#
# install packages
#
#         conda install numpy pandas jupyter -y
